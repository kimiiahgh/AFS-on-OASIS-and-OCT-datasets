# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
# Out:
# Mounted at /content/gdrive

# %%
# %cd '/content/gdrive/My Drive/Colab Notebooks'
# Out:
# /content/gdrive/My Drive/Colab Notebooks

# %%
# !git clone https://github.com/upup123/AAAI-2019-AFS.git
# Out:
# Cloning into 'AAAI-2019-AFS'...
# remote: Enumerating objects: 52, done.
# remote: Total 52 (delta 0), reused 0 (delta 0), pack-reused 52
# Unpacking objects: 100% (52/52), done.

# %%
# %tensorflow_version 1.x
# Out:
# TensorFlow 1.x selected.

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 1.15.2

# %%
# %cd '/content/gdrive/My Drive/Colab Notebooks/AAAI-2019-AFS'
# Out:
# /content/gdrive/My Drive/Colab Notebooks/AAAI-2019-AFS

# %%
# %matplotlib inline

# %%
#OCT datset:
# !python main.py
# Out:
# WARNING:tensorflow:From /content/gdrive/My Drive/Colab Notebooks/AAAI-2019-AFS/model.py:5: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /content/gdrive/My Drive/Colab Notebooks/AAAI-2019-AFS/model.py:9: The name tf.add_to_collection is deprecated. Please use tf.compat.v1.add_to_collection instead.
#
# WARNING:tensorflow:From /content/gdrive/My Drive/Colab Notebooks/AAAI-2019-AFS/model.py:12: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# WARNING:tensorflow:From /content/gdrive/My Drive/Colab Notebooks/AAAI-2019-AFS/model.py:14: The name tf.truncated_normal is deprecated. Please use tf.random.truncated_normal instead.

# %%
# %cd '/content/gdrive/My Drive/Colab Notebooks/AAAI-2019-AFS'
#mnist_rc
# !python main3.py
# Out:
# /content/gdrive/My Drive/Colab Notebooks/AAAI-2019-AFS
# WARNING:tensorflow:From /content/gdrive/My Drive/Colab Notebooks/AAAI-2019-AFS/model.py:5: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /content/gdrive/My Drive/Colab Notebooks/AAAI-2019-AFS/model.py:9: The name tf.add_to_collection is deprecated. Please use tf.compat.v1.add_to_collection instead.
#
# WARNING:tensorflow:From /content/gdrive/My Drive/Colab Notebooks/AAAI-2019-AFS/model.py:12: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# WARNING:tensorflow:From /content/gdrive/My Drive/Colab Notebooks/AAAI-2019-AFS/model.py:14: The name tf.truncated_normal is deprecated. Please use tf.random.truncated_normal instead.
#
# WARNING:tensorflow:From /content/gdrive/My Drive/Colab Notebooks/AAAI-2019-AFS/model.py:51: The name tf.trainable_variables is deprecated. Please use tf.compat.v1.trainable_variables instead.
#
# ...

# %%
# %cd '/content/gdrive/My Drive/Colab Notebooks/AAAI-2019-AFS'
#OASIS
# !python main4.py
# Out:
# /content/gdrive/My Drive/Colab Notebooks/AAAI-2019-AFS
# WARNING:tensorflow:From /content/gdrive/My Drive/Colab Notebooks/AAAI-2019-AFS/model.py:5: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /content/gdrive/My Drive/Colab Notebooks/AAAI-2019-AFS/model.py:9: The name tf.add_to_collection is deprecated. Please use tf.compat.v1.add_to_collection instead.
#
# WARNING:tensorflow:From /content/gdrive/My Drive/Colab Notebooks/AAAI-2019-AFS/model.py:12: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# WARNING:tensorflow:From /content/gdrive/My Drive/Colab Notebooks/AAAI-2019-AFS/model.py:14: The name tf.truncated_normal is deprecated. Please use tf.random.truncated_normal instead.
#
# WARNING:tensorflow:From /content/gdrive/My Drive/Colab Notebooks/AAAI-2019-AFS/model.py:51: The name tf.trainable_variables is deprecated. Please use tf.compat.v1.trainable_variables instead.
#
# ...
